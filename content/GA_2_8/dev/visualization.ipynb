# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# from vis import *
from tickets import *
from minutes import *

# %%
Minutes.get_minutes([['a','may'], [29, 3], 0, [5, 9, 9]])
# Minutes.get_absolute_day(5,5)
# Out:
# [41765, 41769, 43205, 43209, 44645, 44649, 46085, 46089, 47525, 47529]

# %%
y = slice(2)
x=[2,5,3,2,3,5,2,2]
x.pop(-1)
print(x)
# Out:
# [2, 5, 3, 2, 3, 5, 2]

# %%
a = list(range(1,6+1))
print(a)
a = a[1:]
print(a)
for i in range(4,4):
    print(i)
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, 3, 4, 5, 6]

# %%
a=4
x=[2, 5, 7, 8]
p = []
p.extend([i + a for i in x])
print(p)
# Out:
# [6, 9, 11, 12]

# %%
t = Tickets()
t.status()
t.add([['April', 'May'], [25, 5], [2, 5, 7], [0, 20]])
t.status()
t.add(['April', 27], True)
t.status()
# t.show()
t.show()
# Out:
# Name: no name
# Reference: April 1
# Days: 60
# Number of tickets: 0
# Cost for all tickets: 0.0
#
# Name: no name
# Reference: April 1
# Days: 60
# Number of tickets: 693
# Cost for all tickets: 2079.0
#
# Currently have: 693
# Attempting to add: 1440
# Duplicates: 63
# Net change: 2007
# New total: 2700
# Update successful
# Number of tickets: 2700
# Name: no name
# Reference: April 1
# Days: 60
# Number of tickets: 2700
# Cost for all tickets: 8100.0

# %%
t.add([5, [2, 8]])
t.show()

# %%
t.show()

# %% [markdown]
# ```
# reference_day = "April 1"
# plot_probabilities
# plot_tickets

# %%
distribution_day = (33, 6.5)
distribution_min = (863, 190)

plot_limits = (0, 60)

tickets = np.zeros((60, 1440))
